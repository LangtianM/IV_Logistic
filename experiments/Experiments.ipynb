# %%
from IVClassification import *
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from sklearn.preprocessing import StandardScaler

matplotlib.rcParams.update(matplotlib.rcParamsDefault)

# %% [markdown]
# ## Model
# let $g(p) = \ln\left( \frac{p}{1-p} \right)$ be the logit function, $X$ be the treatment, $Y$ be the binary outcome, $U$ be the confounder, and $Z$ be the instrumental variable. The generalized linear model can be defined as:
# $$
# g(\mathbb{E}[Y|X, U])= \beta^{T}X + \eta U
# $$
# where
# $$
# \mathbb{E}[X^{T}U]\neq 0, \quad \mathbb{E}[Z^{T}U]=0
# $$

# %% [markdown]
# Let the structrual equation be linear:
# $$
# X = \alpha Z + \gamma U + \epsilon
# $$

# %% [markdown]
# ### The effect of $\beta$

# %%
lg_dif = np.array([])
tslg_dif = np.array([])
s3lg_dif = np.array([])
gmm_dif = np.array([])
res_dif = np.array([])
ref_dif = np.array([])

para_range = np.linspace(-10, 10, 100)

for beta in para_range:
    
    data = sim_data(n=10000, beta=beta)
    
    ref_lg = LogisticRegression()
    complete_data = np.concatenate((data.X.reshape(-1, 1), data.U.reshape(-1, 1)), axis=1)
    ref_lg.fit(complete_data, data.Y)
    ref_dif = np.append(ref_dif, np.abs(ref_lg.coef_[0][0] - beta))
    
    lg = LogisticRegression()
    lg.fit(data.X.reshape(-1, 1), data.Y)
    
    lg_dif = np.append(lg_dif, np.abs(lg.coef_ - beta))
    
    tslg = two_stage_logit()
    tslg.fit(data.X, data.Y, data.Z)
    tslg_dif = np.append(tslg_dif, np.abs(tslg.coef_ - beta))
    
    # s3lg = three_stage_logit()
    # s3lg.fit(data.X, data.Y, data.Z)
    # s3lg_dif = np.append(s3lg_dif, np.abs(s3lg.coef_ - beta))
    
    gmm = GMM_logit()
    gmm.fit(data.X, data.Y, data.Z)
    gmm_dif = np.append(gmm_dif, np.abs(gmm.coef_ - beta))
    
    res_model = residual_logit()
    res_model.fit(data.X, data.Y, data.Z)
    res_dif = np.append(res_dif, np.abs(res_model.beta - beta))

# window_size = 20
# window = np.ones(window_size) / window_size
# gmm_dif = np.convolve(gmm_dif, window, mode='same')

# %%
outliers = np.abs(gmm_dif) > 10
gmm_dif[outliers] = np.mean(gmm_dif[~outliers])

plt.figure(figsize=(10, 8))
plt.plot(para_range, lg_dif, label='lg')
plt.plot(para_range, tslg_dif, label='tslg')
plt.plot(para_range, ref_dif, label='ref')
#plt.plot(para_range, s3lg_dif, label='s3lg')
#plt.plot(para_range, gmm_dif, label='gmm')
plt.plot(para_range, res_dif, label='res')
plt.xlabel('beta')
plt.ylabel('difference')
plt.legend()

# %% [markdown]
# The only case where 2 stage logistic regression being consistent is when beta is 0

# %%
lg_coef = np.array([])

para_range = np.linspace(-5, 5, 100)

for beta in para_range:
    
    data = sim_data(n=10000, beta=beta)
    
    lg = LogisticRegression()
    lg.fit(data.X.reshape(-1, 1), data.Y)
    
    lg_coef = np.append(lg_coef, lg.coef_)
    
plt.plot(para_range, lg_coef, label='lg')
plt.plot(para_range, para_range, label='true')
plt.xlabel('beta')
plt.ylabel('coefficient')
plt.legend()

# %% [markdown]
# ### The effect of $\eta$

# %%
k = np.linspace(-1, 8, 100)
lg_coef = np.array([])
tslg_coef = np.array([])
s3lg_coef = np.array([])
gmm_coef = np.array([])
res_coef = np.array([])
ref_coef = np.array([])
beta = 1

for eta in np.power(10, k):
    
    data = sim_data(n=10000, eta=eta, beta=beta)
    
    lg = LogisticRegression()
    lg.fit(data.X.reshape(-1, 1), data.Y)
    lg_coef = np.append(lg_coef, lg.coef_)
    
    tslg = two_stage_logit()
    tslg.fit(data.X, data.Y, data.Z)
    tslg_coef = np.append(tslg_coef, tslg.coef_)
    
    ref_lg = LogisticRegression()
    complete_data = np.concatenate((data.X.reshape(-1, 1), data.U.reshape(-1, 1)), axis=1)
    ref_lg.fit(complete_data, data.Y)
    ref_coef = np.append(ref_coef, ref_lg.coef_[0][0])
    
    # s3lg = three_stage_logit()
    # s3lg.fit(data.X, data.Y, data.Z)
    # s3lg_coef = np.append(s3lg_coef, s3lg.coef_)
    
    # gmm = GMM_logit()
    # gmm.fit(data.X, data.Y, data.Z)
    # gmm_coef = np.append(gmm_coef, gmm.coef_)
    
    res_model = residual_logit()
    res_model.fit(data.X, data.Y, data.Z)
    res_coef = np.append(res_coef, res_model.beta)
    
plt.figure(figsize=(10, 8))
plt.plot(k, ref_coef, label='ref')
plt.plot(k, lg_coef, label='lg')
plt.plot(k, tslg_coef, label='tslg')
# plt.plot(k, s3lg_coef, label='s3lg')
# plt.plot(k, gmm_coef, label='gmm')
plt.plot(k, res_coef, label='res')
plt.plot(k, beta * np.ones(100), label='true')
#plt.xticks(k[::20], [f'$10^{{{round(ki, 1)}}}$' for ki in k[::20]])
plt.xlabel('eta')
plt.ylabel('beta')
plt.legend()

# %%
para_range = np.linspace(-8, 8, 100)
lg_coef = np.array([])
tslg_coef = np.array([])
s3lg_coef = np.array([])
gmm_coef = np.array([])
res_coef = np.array([])
ref_coef = np.array([])
beta = 1

for eta in para_range:
    
    data = sim_data(n=10000, eta=eta, beta=beta)
    
    lg = LogisticRegression()
    lg.fit(data.X.reshape(-1, 1), data.Y)
    lg_coef = np.append(lg_coef, lg.coef_)
    
    tslg = two_stage_logit()
    tslg.fit(data.X, data.Y, data.Z)
    tslg_coef = np.append(tslg_coef, tslg.coef_)
    
    ref_lg = LogisticRegression()
    complete_data = np.concatenate((data.X.reshape(-1, 1), data.U.reshape(-1, 1)), axis=1)
    ref_lg.fit(complete_data, data.Y)
    ref_coef = np.append(ref_coef, ref_lg.coef_[0][0])
    
    # s3lg = three_stage_logit()
    # s3lg.fit(data.X, data.Y, data.Z)
    # s3lg_coef = np.append(s3lg_coef, s3lg.coef_)
    
    # gmm = GMM_logit()
    # gmm.fit(data.X, data.Y, data.Z)
    # gmm_coef = np.append(gmm_coef, gmm.coef_)
    
    res_model = residual_logit()
    res_model.fit(data.X, data.Y, data.Z)
    res_coef = np.append(res_coef, res_model.beta)
    
plt.figure(figsize=(12, 8))
plt.plot(para_range, ref_coef, label='ref')
plt.plot(para_range, lg_coef, label='lg')
plt.plot(para_range, tslg_coef, label='tslg')
# plt.plot(para_range, s3lg_coef, label='s3lg')
# plt.plot(para_range, gmm_coef, label='gmm')
plt.plot(para_range, res_coef, label='res')
plt.plot(para_range, beta * np.ones(100), label='true')
plt.xlabel('eta')
plt.ylabel('beta')
plt.legend()

# %% [markdown]
# ### The effect pf $\gamma$

# %%
k = np.linspace(-2, 6, 200)
lg_coef = np.array([])
tslg_coef = np.array([])
s3lg_coef = np.array([])      
gmm_coef = np.array([])
ref_coef = np.array([])
beta = 3

for gamma in np.power(10, k):
    data = sim_data(n=10000, gamma=gamma, beta=beta)
    
    ref_lg = LogisticRegression()
    complete_data = np.concatenate((data.X.reshape(-1, 1), data.U.reshape(-1, 1)), axis=1)
    ref_lg.fit(complete_data, data.Y)
    ref_coef = np.append(ref_coef, ref_lg.coef_[0][0])
    
    lg = LogisticRegression()
    lg.fit(data.X.reshape(-1, 1), data.Y)
    lg_coef = np.append(lg_coef, lg.coef_)
    
    tslg = two_stage_logit()
    tslg.fit(data.X, data.Y, data.Z)
    tslg_coef = np.append(tslg_coef, tslg.coef_)
    
    # s3lg = three_stage_logit()
    # s3lg.fit(data.X, data.Y, data.Z)
    # s3lg_coef = np.append(s3lg_coef, s3lg.coef_)
    
    gmm = GMM_logit()
    gmm.fit(data.X, data.Y, data.Z)
    gmm_coef = np.append(gmm_coef, gmm.coef_)
    
    
# Detect outliers of gmm_coef and substitute them with the mean of other values
outliers = np.abs(gmm_coef - beta) > 5
gmm_coef[outliers] = np.mean(gmm_coef[~outliers])

plt.figure(figsize=(12, 8))
plt.plot(k, lg_coef, label='lg')
plt.plot(k, tslg_coef, label='tslg')
#plt.plot(k, s3lg_coef, label='s3lg')
plt.plot(k, gmm_coef, label = 'gmm', alpha=0.5)
plt.plot(k, ref_coef, label='ref')
plt.plot(k, beta * np.ones(200), label='true')
plt.xticks(k[::20], [f'$10^{{{round(ki, 1)}}}$' for ki in k[::20]])
plt.xlabel('gamma')
plt.ylabel('beta')
plt.legend()

# %%
k = np.linspace(-2, 6, 200)
lg_coef = np.array([])
tslg_coef = np.array([])
s3lg_coef = np.array([])      
gmm_coef = np.array([])
beta = 1

gamma = 100

for eta in range(100):
    data = sim_data(n=10000, eta=eta, gamma=gamma, beta=beta)
    
    lg = LogisticRegression()
    lg.fit(data.X.reshape(-1, 1), data.Y)
    lg_coef = np.append(lg_coef, lg.coef_)
    

plt.figure(figsize=(8, 8))
fig, axs = plt.subplots(1, 2, figsize=(12, 6))

# Plot 1
axs[0].plot(range(10), lg_coef[:10])
axs[0].set_title('Plot 1')
axs[0].set_xlabel('eta')
axs[0].set_ylabel('beta_hat')

# Plot 2
axs[1].plot(range(100), lg_coef)
axs[1].set_title('Plot 2')
axs[1].set_xlabel('eta')
axs[1].set_ylabel('beta_hat')

plt.tight_layout()
plt.show()

# %%
k = np.linspace(-2, 6, 200)
lg_coef = np.array([])
tslg_coef = np.array([])
s3lg_coef = np.array([])      
gmm_coef = np.array([])
beta = 1

gamma = 100

for eta in range(100):
    data = sim_data(n=10000, eta=eta, gamma=gamma, beta=beta, alpha=0)
    
    lg = LogisticRegression()
    lg.fit(data.X.reshape(-1, 1), data.Y)
    lg_coef = np.append(lg_coef, lg.coef_)
    

plt.figure(figsize=(8, 8))
fig, axs = plt.subplots(1, 2, figsize=(12, 6))

# Plot 1
axs[0].plot(range(10), lg_coef[:10])
axs[0].set_title('Plot 1')
axs[0].set_xlabel('eta')
axs[0].set_ylabel('beta_hat')

# Plot 2
axs[1].plot(range(100), lg_coef)
axs[1].set_title('Plot 2')
axs[1].set_xlabel('eta')
axs[1].set_ylabel('beta_hat')

plt.tight_layout()
plt.show()

# %%
k = np.linspace(0.1, 6, 100)
lg_coef = np.array([])
tslg_coef = np.array([])
s3lg_coef = np.array([])      
gmm_coef = np.array([])
res_coef = np.array([])
beta = 1

for gamma in np.power(10, k):
    data = sim_data(n=10000, gamma=gamma, beta=beta)
    
    lg = LogisticRegression()
    lg.fit(data.X.reshape(-1, 1), data.Y)
    lg_coef = np.append(lg_coef, lg.coef_)
    
    tslg = two_stage_logit()
    tslg.fit(data.X, data.Y, data.Z)
    tslg_coef = np.append(tslg_coef, tslg.coef_)
    
    # s3lg = three_stage_logit()
    # s3lg.fit(data.X, data.Y, data.Z)
    # s3lg_coef = np.append(s3lg_coef, s3lg.coef_)
    
    res_model = residual_logit()
    res_model.fit(data.X, data.Y, data.Z)
    res_coef = np.append(res_coef, res_model.beta)
    
    gmm = GMM_logit()
    gmm.fit(data.X, data.Y, data.Z)
    gmm_coef = np.append(gmm_coef, gmm.coef_)
    
outliers = np.abs(gmm_coef - beta) > 5
gmm_coef[outliers] = np.mean(gmm_coef[~outliers])
    
plt.figure(figsize=(12, 8))
plt.plot(k, beta * np.ones(100), label='true', color='red')
plt.plot(k, lg_coef, label='lg')
plt.plot(k, tslg_coef, label='tslg')
#plt.plot(k, s3lg_coef, label='s3lg')
plt.plot(k, res_coef, label='res')
plt.plot(k, gmm_coef, label = 'gmm', alpha=0.4)

plt.xticks(k[::20], [f'$10^{{{round(ki, 1)}}}$' for ki in k[::20]])
plt.xlabel('gamma')
plt.ylabel('beta')
plt.legend()

# %%
para_range = np.linspace(-5, 5, 100)
lg_coef = np.array([])
tslg_coef = np.array([])
s3lg_coef = np.array([])
gmm_coef = np.array([])
res_coef = np.array([])
beta = 1

for gamma in para_range:
        
        data = sim_data(n=10000, gamma=gamma, beta=beta)
        
        lg = LogisticRegression()
        lg.fit(data.X.reshape(-1, 1), data.Y)
        lg_coef = np.append(lg_coef, lg.coef_)
        
        tslg = two_stage_logit()
        tslg.fit(data.X, data.Y, data.Z)
        tslg_coef = np.append(tslg_coef, tslg.coef_)
        
        # s3lg = three_stage_logit()
        # s3lg.fit(data.X, data.Y, data.Z)
        # s3lg_coef = np.append(s3lg_coef, s3lg.coef_)
        
        # gmm = GMM_logit()
        # gmm.fit(data.X, data.Y, data.Z)
        # gmm_coef = np.append(gmm_coef, gmm.coef_)
        
        res_model = residual_logit()
        res_model.fit(data.X, data.Y, data.Z)
        res_coef = np.append(res_coef, res_model.beta)

# %%
plt.figure(figsize=(10, 8))        
plt.plot(para_range, lg_coef, label='lg')
plt.plot(para_range, tslg_coef, label='tslg')
plt.plot(para_range, s3lg_coef, label='s3lg')
# plt.plot(para_range, gmm_coef, label='gmm')
plt.plot(para_range, res_coef, label='res')
plt.plot(para_range, beta * np.ones(100), label='true')
plt.xlabel('gamma')
plt.ylabel('beta')
plt.legend()

# %%
k = np.linspace(-1, 6, 100)
lg_coef = np.array([])
tslg_coef = np.array([])
s3lg_coef = np.array([])      
gmm_coef = np.array([])
res_coef = np.array([])
beta = 30

for gamma in np.power(10, k):
    
    data = sim_data(n=10000, gamma=gamma, beta=beta)
    
    lg = LogisticRegression()
    lg.fit(data.X.reshape(-1, 1), data.Y)
    lg_coef = np.append(lg_coef, lg.coef_)
    
    tslg = two_stage_logit()
    tslg.fit(data.X, data.Y, data.Z)
    tslg_coef = np.append(tslg_coef, tslg.coef_)
    
    res_model = residual_logit()
    res_model.fit(data.X, data.Y, data.Z)
    res_coef = np.append(res_coef, res_model.beta)
    
    # s3lg = three_stage_logit()
    # s3lg.fit(data.X, data.Y, data.Z)
    # s3lg_coef = np.append(s3lg_coef, s3lg.coef_)
    
    gmm = GMM_logit()
    gmm.fit(data.X, data.Y, data.Z)
    gmm_coef = np.append(gmm_coef, gmm.coef_)
    
outliers = np.abs(gmm_coef - beta) > 10
gmm_coef[outliers] = np.mean(gmm_coef[~outliers])
    
plt.figure(figsize=(12, 8))
plt.plot(k, lg_coef, label='lg')
plt.plot(k, tslg_coef, label='tslg')
plt.plot(k, res_coef, label='res')
#plt.plot(k, s3lg_coef, label='s3lg')
plt.plot(k, gmm_coef, label = 'gmm', alpha=0.4)
plt.plot(k, beta * np.ones(100), label='true')
plt.xticks(k[::10], [f'$10^{{{round(ki, 1)}}}$' for ki in k[::10]])
plt.xlabel('gamma')
plt.ylabel('beta')
plt.legend()

# %%
k = np.linspace(-6, 6, 200)
lg_coef = np.array([])
tslg_coef = np.array([])
s3lg_coef = np.array([])      
gmm_coef = np.array([])

beta = 20

for gamma in np.power(10, k):
    data = sim_data(n=10000, gamma=gamma, beta=beta)
    
    lg = LogisticRegression()
    lg.fit(data.X.reshape(-1, 1), data.Y)
    lg_coef = np.append(lg_coef, lg.coef_)
    
    tslg = two_stage_logit()
    tslg.fit(data.X, data.Y, data.Z)
    tslg_coef = np.append(tslg_coef, tslg.coef_)
    
    
    
    # s3lg = three_stage_logit()
    # s3lg.fit(data.X, data.Y, data.Z)
    # s3lg_coef = np.append(s3lg_coef, s3lg.coef_)
    
    # gmm = GMM_logit()
    # gmm.fit(data.X, data.Y, data.Z)
    # gmm_coef = np.append(gmm_coef, gmm.coef_)
    
plt.figure(figsize=(12, 8))
plt.plot(k, lg_coef, label='lg')
plt.plot(k, tslg_coef, label='tslg')
#plt.plot(k, s3lg_coef, label='s3lg')
# plt.plot(k, gmm_coef, label = 'gmm')
plt.plot(k, beta * np.ones(200), label='true')
plt.xticks(k[::20], [f'$10^{{{round(ki, 1)}}}$' for ki in k[::20]])
plt.xlabel('gamma')
plt.ylabel('beta')
plt.legend()

# %% [markdown]
# ### effect of alpha

# %%
k = np.linspace(-2, 8, 100)
lg_coef = np.array([])
tslg_coef = np.array([])
s3lg_coef = np.array([])
gmm_coef = np.array([])
res_coef = np.array([])
ref_coef = np.array([])

beta = 5

for alpha in np.power(10, k):
    data = sim_data(n=10000, alpha=alpha, beta=beta)
    
    ref_lg = LogisticRegression()
    complete_data = np.concatenate((data.X.reshape(-1, 1), data.U.reshape(-1, 1)), axis=1)
    ref_lg.fit(complete_data, data.Y)
    ref_coef = np.append(ref_coef, ref_lg.coef_[0][0])
    
    
    lg = LogisticRegression()
    lg.fit(data.X.reshape(-1, 1), data.Y)
    lg_coef = np.append(lg_coef, lg.coef_)
    
    tslg = two_stage_logit()
    tslg.fit(data.X, data.Y, data.Z)
    tslg_coef = np.append(tslg_coef, tslg.coef_)
    
    res_model = residual_logit()
    res_model.fit(data.X, data.Y, data.Z)
    res_coef = np.append(res_coef, res_model.beta)
    
    # s3lg = three_stage_logit()
    # s3lg.fit(data.X, data.Y, data.Z)
    # s3lg_coef = np.append(s3lg_coef, s3lg.coef_)
    
    gmm = GMM_logit()
    gmm.fit(data.X, data.Y, data.Z)
    gmm_coef = np.append(gmm_coef, gmm.coef_)
    
outliers = np.abs(gmm_coef - beta) > 20
gmm_coef[outliers] = np.mean(gmm_coef[~outliers]) 
    
plt.figure(figsize=(12, 8))
plt.plot(k, ref_coef, label='ref')
plt.plot(k, lg_coef, label='lg')
plt.plot(k, tslg_coef, label='tslg')
#plt.plot(k, s3lg_coef, label='s3lg')
plt.plot(k, gmm_coef, label='gmm')
plt.plot(k, res_coef, label='res')
plt.plot(k, beta * np.ones(100), label='true')
plt.xticks(k[::10], [f'$10^{{{round(ki, 1)}}}$' for ki in k[::10]])
plt.xlabel('alpha')
plt.ylabel('beta')
plt.legend()
